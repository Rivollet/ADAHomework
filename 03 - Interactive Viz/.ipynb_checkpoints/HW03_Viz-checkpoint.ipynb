# %% [markdown]
# # HW 03 - Interactive Viz

# %% [markdown]
# We will show the money that flowed to each canton since 1975 (although the data from these days is not very reliable)

# %%
#Usual imports
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# to display the position on a map
import folium
# for querying the canton of a university
#from geopy.geocoders import Nominatim
from geopy.geocoders import GoogleV3


import seaborn as sns
sns.set_context('notebook')

# %% [markdown]
# # Importing the Data
# Let's import the data with the project fundings and see what it looks like.

# %%
df = pd.read_csv("P3_GrantExport.csv", sep=";")
df.head(2)
# Out:
#    ﻿"Project Number"                                      Project Title  \
# 0                  1  Schlussband (Bd. VI) der Jacob Burckhardt-Biog...
# 1                  4  Batterie de tests à l'usage des enseignants po...
#
#   Project Title English Responsible Applicant            Funding Instrument  \
# 0                   NaN          Kaegi Werner  Project funding (Div. I-III)
# 1                   NaN    Massarenti Léonard  Project funding (Div. I-III)
#
#   Funding Instrument Hierarchy  \
# 0              Project funding
# 1              Project funding
#
#                                          Institution  \
# 0                                                NaN
# 1  Faculté de Psychologie et des Sciences de l'Ed...
#
#                   University  Discipline Number  \
# 0       Nicht zuteilbar - NA              10302
# 1  Université de Genève - GE              10104
#
#                     Discipline Name  \
# 0                     Swiss history
# 1  Educational science and Pedagogy
#
#                            Discipline Name Hierarchy  Start Date    End Date  \
# 0  Human and Social Sciences;Theology & religious...  01.10.1975  30.09.1976
# 1  Human and Social Sciences;Psychology, educatio...  01.10.1975  30.09.1976
#
#   Approved Amount Keywords
# 0        11619.00      NaN
# 1        41022.00      NaN

# %% [markdown]
# # Cleaning the Data
# Let's remove the grants that have no specified location (the names are German).

# %%
nonIdentifiableUniversities = ['Nicht zuteilbar - NA', 'Firmen/Privatwirtschaft - FP', 
                               'NPO (Biblioth., Museen, Verwalt.) - NPO',
                               'Weitere Institute - FINST',
                               'Weitere Spitäler - ASPIT'
                              ]

df = df[~df.University.isin(nonIdentifiableUniversities)]

def replaceNames(name):
    return name.replace('Eidg.', 'Eidgenössische')
#df['University'] = df['University'].apply(replaceNames)

df.head(2)

# %% [markdown]
# There are some entries where the university field is null (NaN). Although they contain an institution name, we will ignore those because the schema specifies that the institution refers to places that are not in Switzerland and here, we are only interested in the grants received by Swiss universities.

# %%
df = df[df['University'].notnull()]

# check that no universities are null, expect 'true'
print(df[df[['University']].isnull().any(axis=1)].empty)

totalNbGrants = df.shape[0]
print("There are {} grants".format(totalNbGrants))
# Out:
# True
# There are 46304 grants

# %% [markdown]
# # Calling the GeoAPI
# We need to find the cantons the universities are in. It turns out that the Open API is not very usable and that Google's GeoAPI works very well.

# %% [markdown]
# First, we write some functions to hide the Google API key using a simple Caesar cipher. This prevents stupid boots from stealing the API key.

# %%
def encrypt(character, shift):
    startChar = '-'
    endChar = 'z'
    lengthDif = ord(endChar) - ord(startChar) + 1
    return chr(ord(startChar) + (ord(character) - ord(startChar) + shift) % lengthDif)

def decrypt(character, shift):
    return encrypt(character, -shift)

def encryptText(text, shift):
    return "".join(list(map(lambda c: encrypt(c, shift),text)))

def decryptText(text, shift):
    return encryptText(text, -shift)

#shift = 3
#for i in range(45, 123):
    #pass
    #print("{}: {}".format(chr(i), decrypt(encrypt(chr(i), shift), shift)))

# %% [markdown]
# In case, a new API key is needed (because the account is deleted), we have left the code to encrypt it.

# %%
# to avoid stealing by bots
#googleApiKey = "put key here"
#shift = 10

#encryptedAPIKey = encryptText(googleApiKey, shift)
#decryptedAPIKey = decryptText(encryptedAPIKey, shift)
#decryptedText == googleApiKey

#print("The encrypted key is {}".format(encryptedText))

# %%
encryptedGoogleApiKey = 'KS6k]5MiT:6M<7zCi@zKosTXO`OqiUsLmYv2tWu'
googleApiKey = decryptText(encryptedGoogleApiKey, shift = 10)
googleApiKey
# Out:
# 'AIzaSyC_J0zC2-p9_6pAeiJNEVEg_KiBcOlvjMk'

# %% [markdown]
# Test the API with an example

# %%
geolocator = GoogleV3(api_key=googleApiKey, domain='maps.googleapis.com', scheme='https')

location = geolocator.geocode(query="Paul Scherrer Institute", exactly_one=True, components={'country': 'CH'})

location
# Out:
# Location(Paul Scherrer Institut, 5232 Villigen, Switzerland, (47.53961349999999, 8.2240445, 0.0))

# %%
# will return (None, None) if address does not contain the canton
def extract_canton_from_address(address):
    for entry in address:
        if entry['types'] == ['administrative_area_level_1', 'political']:
            #return (None, None)
            return entry['short_name'], entry['long_name']
    return (None, None)

# remove everything after first '-', eg. 'Paul Scherrer Institut - PSI'
# becomes 'Paul Scherrer Institut'
def simplifyUnivName(univName):
    #print(univName)
    splittedName = univName.split('-')
    return splittedName[0] # never an exception
    
print(simplifyUnivName('Paul Scherrer Institut - PSI'))

a, b = extract_canton_from_address(location.raw['address_components'])
a,b

#location.raw['address_components']
# Out:
# Paul Scherrer Institut
# ('AG', 'Aargau')

# %% [markdown]
# To avoid many queries, we will only query on the unique university names. This is very important since Google limits the number of calls.

# %%
# Initialize the Google geolocator
geolocator = GoogleV3(api_key=googleApiKey, domain='maps.googleapis.com', scheme='https')

# Only query unique university names for efficiency reasons
uniqueUniversityNames = df.University.unique()
print("There are {} universities".format(len(uniqueUniversityNames)))

# save the canton short name for each university
universityNameToCanton = {}

for i, univName in enumerate(uniqueUniversityNames):
    #print(univName)
    # Use simpler university name in query because Google doesn't understand
    simplerUnivName = simplifyUnivName(univName)
    
    # get the location
    univLocation = geolocator.geocode(query=simplerUnivName, exactly_one=True, components={'country': 'CH'})

    # get the canton, address name is None if geolocation didn't succeed
    cantonShortName, cantonLongName = extract_canton_from_address(univLocation.raw['address_components'])
    
    # print debugging info to see which universities weren't recognized
    if cantonShortName is None or cantonLongName is None:
        print("Could not locate university with name {} at {}th entry, canton short name={}, long name={}".
              format(univName, i, cantonShortName, cantonLongName))
        print(univLocation.raw['address_components'])
    
    universityNameToCanton[univName] = cantonShortName
    #break # enable for testing to avoid many queries
    

#print(universityNameToCanton)
# Out:
# There are 72 universities
# Could not locate university with name Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL at 6th entry, canton short name=None, long name=None
# [{'short_name': 'CH', 'types': ['country', 'political'], 'long_name': 'Switzerland'}]
# Could not locate university with name Université de Neuchâtel - NE at 7th entry, canton short name=None, long name=None
# [{'short_name': 'CH', 'types': ['country', 'political'], 'long_name': 'Switzerland'}]
# Could not locate university with name Inst. de Hautes Etudes Internat. et du Dév - IHEID at 9th entry, canton short name=None, long name=None
# [{'short_name': 'CH', 'types': ['country', 'political'], 'long_name': 'Switzerland'}]
# Could not locate university with name Schweiz. Institut für Kunstwissenschaft - SIK-ISEA at 15th entry, canton short name=None, long name=None
# [{'short_name': 'CH', 'types': ['country', 'political'], 'long_name': 'Switzerland'}]
# Could not locate university with name SUP della Svizzera italiana - SUPSI at 16th entry, canton short name=None, long name=None
# [{'short_name': 'CH', 'types': ['country', 'political'], 'long_name': 'Switzerland'}]
# Could not locate university with name HES de Suisse occidentale - HES-SO at 17th entry, canton short name=None, long name=None
# [{'short_name': 'CH', 'types': ['country', 'political'], 'long_name': 'Switzerland'}]
# Could not locate university with name Eidg. Anstalt für Wasserversorgung - EAWAG at 21th entry, canton short name=None, long name=None
# [{'short_name': 'CH', 'types': ['country', 'political'], 'long_name': 'Switzerland'}]
# Could not locate university with name Eidg. Material und Prüfungsanstalt - EMPA at 22th entry, canton short name=None, long name=None
# [{'short_name': 'CH', 'types': ['country', 'political'], 'long_name': 'Switzerland'}]
# Could not locate university with name Physikal.-Meteorolog. Observatorium Davos - PMOD at 23th entry, canton short name=None, long name=None
# [{'short_name': 'CH', 'types': ['country', 'political'], 'long_name': 'Switzerland'}]
# Could not locate university with name Berner Fachhochschule - BFH at 24th entry, canton short name=None, long name=None
# [{'short_name': 'CH', 'types': ['country', 'political'], 'long_name': 'Switzerland'}]
# Could not locate university with name Swiss Center for Electronics and Microtech. - CSEM at 25th entry, canton short name=None, long name=None
# [{'short_name': 'CH', 'types': ['country', 'political'], 'long_name': 'Switzerland'}]
# Could not locate university with name AO Research Institute - AORI at 26th entry, canton short name=None, long name=None
# [{'short_name': 'CH', 'types': ['country', 'political'], 'long_name': 'Switzerland'}]
# Could not locate university with name Allergie- und Asthmaforschung - SIAF at 27th entry, canton short name=None, long name=None
# [{'short_name': 'CH', 'types': ['country', 'political'], 'long_name': 'Switzerland'}]
# Could not locate university with name Forschungsinstitut für biologischen Landbau - FIBL at 28th entry, canton short name=None, long name=None
# [{'short_name': 'CH', 'types': ['country', 'political'], 'long_name': 'Switzerland'}]
# Could not locate university with name Friedrich Miescher Institute - FMI at 29th entry, canton short name=None, long name=None
# [{'short_name': 'CH', 'types': ['country', 'political'], 'long_name': 'Switzerland'}]
# Could not locate university with name Forschungsanstalten Agroscope - AGS at 31th entry, canton short name=None, long name=None
# [{'short_name': 'CH', 'types': ['country', 'political'], 'long_name': 'Switzerland'}]
# Could not locate university with name Ente Ospedaliero Cantonale - EOC at 32th entry, canton short name=None, long name=None
# [{'short_name': 'CH', 'types': ['country', 'political'], 'long_name': 'Switzerland'}]
# Could not locate university with name Inst. universit. romand de Santé au Travail - IST at 33th entry, canton short name=None, long name=None
# [{'short_name': 'CH', 'types': ['country', 'political'], 'long_name': 'Switzerland'}]
# Could not locate university with name Eidg. Hochschulinstitut für Berufsbildung - EHB at 34th entry, canton short name=None, long name=None
# [{'short_name': 'CH', 'types': ['country', 'political'], 'long_name': 'Switzerland'}]
# Could not locate university with name Zürcher Fachhochschule (ohne PH) - ZFH at 35th entry, canton short name=None, long name=None
# [{'short_name': 'CH', 'types': ['country', 'political'], 'long_name': 'Switzerland'}]
# Could not locate university with name Fachhochschule Nordwestschweiz (ohne PH) - FHNW at 38th entry, canton short name=None, long name=None
# [{'short_name': 'CH', 'types': ['country', 'political'], 'long_name': 'Switzerland'}]
# Could not locate university with name Centre de rech. sur l'environnement alpin - CREALP at 40th entry, canton short name=None, long name=None
# [{'short_name': 'CH', 'types': ['country', 'political'], 'long_name': 'Switzerland'}]
# Could not locate university with name Idiap Research Institute - IDIAP at 41th entry, canton short name=None, long name=None
# [{'short_name': 'CH', 'types': ['country', 'political'], 'long_name': 'Switzerland'}]
# Could not locate university with name Schweizer Paraplegiker Forschung - SPF at 44th entry, canton short name=None, long name=None
# [{'short_name': 'CH', 'types': ['country', 'political'], 'long_name': 'Switzerland'}]
# Could not locate university with name Forschungsinstitut für Opthalmologie - IRO at 46th entry, canton short name=None, long name=None
# [{'short_name': 'CH', 'types': ['country', 'political'], 'long_name': 'Switzerland'}]
# Could not locate university with name Fachhochschule Ostschweiz - FHO at 48th entry, canton short name=None, long name=None
# [{'short_name': 'CH', 'types': ['country', 'political'], 'long_name': 'Switzerland'}]
# Could not locate university with name Inst. Suisse de Spéléologie et Karstologie - ISSKA at 49th entry, canton short name=None, long name=None
# [{'short_name': 'CH', 'types': ['country', 'political'], 'long_name': 'Switzerland'}]
# Could not locate university with name Swiss Institute of Bioinformatics - SIB at 50th entry, canton short name=None, long name=None
# [{'short_name': 'CH', 'types': ['country', 'political'], 'long_name': 'Switzerland'}]
# Could not locate university with name Forschungskommission SAGW at 53th entry, canton short name=None, long name=None
# [{'short_name': 'CH', 'types': ['country', 'political'], 'long_name': 'Switzerland'}]
# Could not locate university with name Istituto Svizzero di Roma - ISR at 54th entry, canton short name=None, long name=None
# [{'short_name': 'CH', 'types': ['country', 'political'], 'long_name': 'Switzerland'}]
# Could not locate university with name Pädag. Hochschule Tessin (Teilschule SUPSI) - ASP at 55th entry, canton short name=None, long name=None
# [{'short_name': 'CH', 'types': ['country', 'political'], 'long_name': 'Switzerland'}]
# Could not locate university with name Haute école pédagogique fribourgeoise - HEPFR at 56th entry, canton short name=None, long name=None
# [{'short_name': 'CH', 'types': ['country', 'political'], 'long_name': 'Switzerland'}]
# Could not locate university with name Fachhochschule Kalaidos - FHKD at 60th entry, canton short name=None, long name=None
# [{'short_name': 'CH', 'types': ['country', 'political'], 'long_name': 'Switzerland'}]
# Could not locate university with name Schweizer Kompetenzzentrum Sozialwissensch. - FORS at 61th entry, canton short name=None, long name=None
# [{'short_name': 'CH', 'types': ['country', 'political'], 'long_name': 'Switzerland'}]
# Could not locate university with name Pädagogische Hochschule Nordwestschweiz - PHFHNW at 68th entry, canton short name=None, long name=None
# [{'short_name': 'CH', 'types': ['country', 'political'], 'long_name': 'Switzerland'}]
# Could not locate university with name Fernfachhochschule Schweiz (Mitglied SUPSI) - FFHS at 71th entry, canton short name=None, long name=None
# [{'short_name': 'CH', 'types': ['country', 'political'], 'long_name': 'Switzerland'}]
# {'SUP della Svizzera italiana - SUPSI': None, 'Hochschule Luzern - HSLU': 'LU', 'AO Research Institute - AORI': None, 'Pädagogische Hochschule Nordwestschweiz - PHFHNW': None, 'EPF Lausanne - EPFL': 'VD', 'Paul Scherrer Institut - PSI': 'AG', 'Zürcher Fachhochschule (ohne PH) - ZFH': None, 'Schweizer Paraplegiker Forschung - SPF': None, 'Pädagogische Hochschule Thurgau - PHTG': 'TG', 'Pädagogische Hochschule St. Gallen - PHSG': 'SG', 'Pädagogische Hochschule Zug - PHZG': 'ZG', 'Friedrich Miescher Institute - FMI': None, 'Berner Fachhochschule - BFH': None, 'Université de Neuchâtel - NE': None, 'ETH Zürich - ETHZ': 'ZH', 'Università della Svizzera italiana - USI': 'TI', 'Kantonsspital St. Gallen - KSPSG': 'SG', 'Pädagogische Hochschule Zürich - PHZFH': 'ZH', 'Pädag. Hochschule Tessin (Teilschule SUPSI) - ASP': None, 'Facoltà di Teologia di Lugano - FTL': 'TI', 'Universität Basel - BS': 'BS', 'Physikal.-Meteorolog. Observatorium Davos - PMOD': None, 'Institut für Kulturforschung Graubünden - IKG': 'GR', 'Allergie- und Asthmaforschung - SIAF': None, 'Institut Universitaire Kurt Bösch - IUKB': 'ZG', 'Inst. de Hautes Etudes Internat. et du Dév - IHEID': None, 'Forschungskommission SAGW': None, 'Fachhochschule Kalaidos - FHKD': None, 'Haute école pédagogique BE, JU, NE - HEPBEJUNE': 'NE', 'Robert Walser-Stiftung Bern - RWS': 'ZH', 'Staatsunabh. Theologische Hochschule Basel - STHB': 'BS', 'Universität Bern - BE': 'BE', 'Pädagogische Hochschule Schaffhausen - PHSH': 'SH', 'Biotechnologie Institut Thurgau - BITG': 'TG', 'Schweiz. Institut für Kunstwissenschaft - SIK-ISEA': None, 'Forschungsanstalten Agroscope - AGS': None, 'Fachhochschule Ostschweiz - FHO': None, 'Instituto Ricerche Solari Locarno - IRSOL': 'TI', 'Forschungsinstitut für Opthalmologie - IRO': None, 'Istituto Svizzero di Roma - ISR': None, 'Pädagogische Hochschule Schwyz - PHSZ': 'SZ', 'Swiss Institute of Bioinformatics - SIB': None, 'Eidg. Anstalt für Wasserversorgung - EAWAG': None, 'Franklin University Switzerland - FUS': 'TI', 'Eidg. Material und Prüfungsanstalt - EMPA': None, 'Pädagogische Hochschule Graubünden - PHGR': 'GR', 'Interkant. Hochschule für Heilpädagogik ZH - HfH': 'ZH', 'Universität Zürich - ZH': 'ZH', 'Haute école pédagogique fribourgeoise - HEPFR': None, 'Université de Genève - GE': 'GE', "Centre de rech. sur l'environnement alpin - CREALP": None, 'Fernfachhochschule Schweiz (Mitglied SUPSI) - FFHS': None, 'Swiss Center for Electronics and Microtech. - CSEM': None, 'Pädagogische Hochschule Wallis - PHVS': 'VS', 'Inst. Suisse de Spéléologie et Karstologie - ISSKA': None, 'Universität Luzern - LU': 'LU', 'Schweiz. Hochschule für Logopädie Rorschach - SHLR': 'SG', 'Haute école pédagogique du canton de Vaud - HEPL': 'VD', 'Eidg. Hochschulinstitut für Berufsbildung - EHB': None, 'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL': None, 'Universität St. Gallen - SG': 'SG', 'Pädagogische Hochschule Bern - PHBern': 'BE', 'Schweizer Kompetenzzentrum Sozialwissensch. - FORS': None, 'Inst. universit. romand de Santé au Travail - IST': None, 'Université de Lausanne - LA': 'VD', 'Forschungsinstitut für biologischen Landbau - FIBL': None, 'Ente Ospedaliero Cantonale - EOC': None, 'Université de Fribourg - FR': 'FR', 'Pädagogische Hochschule Luzern - PHLU': 'LU', 'Fachhochschule Nordwestschweiz (ohne PH) - FHNW': None, 'Idiap Research Institute - IDIAP': None, 'HES de Suisse occidentale - HES-SO': None}

# %% [markdown]
# Let's see how many universities we have mapped so far.

# %%
def findNumberUnmappedUniversities(univToCantonMap):
    
    mappedUniversityNames = filter(lambda key: univToCantonMap[key] is not None, df.University)
    nbGrantsMapped = np.sum(df[['University']].isin(mappedUniversityNames))
    
    return nbGrantsMapped

nbGrantsMapped = findNumberUnmappedUniversities(universityNameToCanton)
print("Percentage of grants mapped: {}".format(nbGrantsMapped/totalNbGrants))
# Out:
# Percentage of grants mapped: University    0.906488
# dtype: float64

# %% [markdown]
# We want at least a mapping of 95% of the universities. Where does it come from? We look at the universities that are not yet mapped.

# %%
nonMappedUniversityNames = list(filter(lambda key: universityNameToCanton[key] is None, df.University))
nonMappedUniversityNames
# Out:
# ['Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Université de Neuchâtel - NE',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Université de Neuchâtel - NE',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Université de Neuchâtel - NE',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Schweiz. Institut für Kunstwissenschaft - SIK-ISEA',
#  'Université de Neuchâtel - NE',
#  'SUP della Svizzera italiana - SUPSI',
#  'HES de Suisse occidentale - HES-SO',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Schweiz. Institut für Kunstwissenschaft - SIK-ISEA',
#  'Université de Neuchâtel - NE',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Université de Neuchâtel - NE',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Schweiz. Institut für Kunstwissenschaft - SIK-ISEA',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Université de Neuchâtel - NE',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Université de Neuchâtel - NE',
#  'Schweiz. Institut für Kunstwissenschaft - SIK-ISEA',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Université de Neuchâtel - NE',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Université de Neuchâtel - NE',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Université de Neuchâtel - NE',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Université de Neuchâtel - NE',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Université de Neuchâtel - NE',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Université de Neuchâtel - NE',
#  'Berner Fachhochschule - BFH',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Swiss Center for Electronics and Microtech. - CSEM',
#  'Université de Neuchâtel - NE',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Swiss Center for Electronics and Microtech. - CSEM',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Swiss Center for Electronics and Microtech. - CSEM',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'SUP della Svizzera italiana - SUPSI',
#  'Université de Neuchâtel - NE',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Université de Neuchâtel - NE',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'SUP della Svizzera italiana - SUPSI',
#  'Université de Neuchâtel - NE',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Swiss Center for Electronics and Microtech. - CSEM',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'SUP della Svizzera italiana - SUPSI',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'AO Research Institute - AORI',
#  'Allergie- und Asthmaforschung - SIAF',
#  'Université de Neuchâtel - NE',
#  'AO Research Institute - AORI',
#  'Forschungsinstitut für biologischen Landbau - FIBL',
#  'AO Research Institute - AORI',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Friedrich Miescher Institute - FMI',
#  'Friedrich Miescher Institute - FMI',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Forschungsanstalten Agroscope - AGS',
#  'Université de Neuchâtel - NE',
#  'Allergie- und Asthmaforschung - SIAF',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'AO Research Institute - AORI',
#  'AO Research Institute - AORI',
#  'Forschungsanstalten Agroscope - AGS',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Friedrich Miescher Institute - FMI',
#  'Allergie- und Asthmaforschung - SIAF',
#  'Forschungsinstitut für biologischen Landbau - FIBL',
#  'Université de Neuchâtel - NE',
#  'Ente Ospedaliero Cantonale - EOC',
#  'Allergie- und Asthmaforschung - SIAF',
#  'Forschungsanstalten Agroscope - AGS',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'SUP della Svizzera italiana - SUPSI',
#  'Université de Neuchâtel - NE',
#  'Inst. universit. romand de Santé au Travail - IST',
#  'Inst. universit. romand de Santé au Travail - IST',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Friedrich Miescher Institute - FMI',
#  'Allergie- und Asthmaforschung - SIAF',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Forschungsanstalten Agroscope - AGS',
#  'Forschungsinstitut für biologischen Landbau - FIBL',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Forschungsanstalten Agroscope - AGS',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Université de Neuchâtel - NE',
#  'Friedrich Miescher Institute - FMI',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Allergie- und Asthmaforschung - SIAF',
#  'SUP della Svizzera italiana - SUPSI',
#  'Forschungsanstalten Agroscope - AGS',
#  'Ente Ospedaliero Cantonale - EOC',
#  'Inst. universit. romand de Santé au Travail - IST',
#  'Allergie- und Asthmaforschung - SIAF',
#  'Forschungsanstalten Agroscope - AGS',
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Forschungsanstalten Agroscope - AGS',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'AO Research Institute - AORI',
#  'Inst. universit. romand de Santé au Travail - IST',
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Forschungsanstalten Agroscope - AGS',
#  'SUP della Svizzera italiana - SUPSI',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Inst. universit. romand de Santé au Travail - IST',
#  'Ente Ospedaliero Cantonale - EOC',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Friedrich Miescher Institute - FMI',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'SUP della Svizzera italiana - SUPSI',
#  'Allergie- und Asthmaforschung - SIAF',
#  'Université de Neuchâtel - NE',
#  'SUP della Svizzera italiana - SUPSI',
#  'Ente Ospedaliero Cantonale - EOC',
#  'Université de Neuchâtel - NE',
#  'SUP della Svizzera italiana - SUPSI',
#  'Université de Neuchâtel - NE',
#  'Forschungsanstalten Agroscope - AGS',
#  'AO Research Institute - AORI',
#  'Friedrich Miescher Institute - FMI',
#  'Université de Neuchâtel - NE',
#  'Forschungsanstalten Agroscope - AGS',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Forschungsanstalten Agroscope - AGS',
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Inst. universit. romand de Santé au Travail - IST',
#  'Ente Ospedaliero Cantonale - EOC',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'SUP della Svizzera italiana - SUPSI',
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Université de Neuchâtel - NE',
#  'SUP della Svizzera italiana - SUPSI',
#  'Inst. universit. romand de Santé au Travail - IST',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'SUP della Svizzera italiana - SUPSI',
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Université de Neuchâtel - NE',
#  'Forschungsanstalten Agroscope - AGS',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Université de Neuchâtel - NE',
#  'Swiss Center for Electronics and Microtech. - CSEM',
#  'Eidg. Hochschulinstitut für Berufsbildung - EHB',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Forschungsanstalten Agroscope - AGS',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Forschungsanstalten Agroscope - AGS',
#  'Université de Neuchâtel - NE',
#  'Eidg. Hochschulinstitut für Berufsbildung - EHB',
#  'Université de Neuchâtel - NE',
#  'Swiss Center for Electronics and Microtech. - CSEM',
#  'Swiss Center for Electronics and Microtech. - CSEM',
#  'Swiss Center for Electronics and Microtech. - CSEM',
#  'Swiss Center for Electronics and Microtech. - CSEM',
#  'Swiss Center for Electronics and Microtech. - CSEM',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Forschungsanstalten Agroscope - AGS',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Zürcher Fachhochschule (ohne PH) - ZFH',
#  'Eidg. Hochschulinstitut für Berufsbildung - EHB',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Schweiz. Institut für Kunstwissenschaft - SIK-ISEA',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Université de Neuchâtel - NE',
#  'Schweiz. Institut für Kunstwissenschaft - SIK-ISEA',
#  'Forschungsanstalten Agroscope - AGS',
#  'Eidg. Hochschulinstitut für Berufsbildung - EHB',
#  'Université de Neuchâtel - NE',
#  'Forschungsanstalten Agroscope - AGS',
#  'Forschungsanstalten Agroscope - AGS',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Forschungsanstalten Agroscope - AGS',
#  'Forschungsanstalten Agroscope - AGS',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Université de Neuchâtel - NE',
#  'Forschungsanstalten Agroscope - AGS',
#  'Forschungsanstalten Agroscope - AGS',
#  'Forschungsanstalten Agroscope - AGS',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Forschungsanstalten Agroscope - AGS',
#  'Université de Neuchâtel - NE',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Université de Neuchâtel - NE',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Forschungsanstalten Agroscope - AGS',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Swiss Center for Electronics and Microtech. - CSEM',
#  'Forschungsanstalten Agroscope - AGS',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'SUP della Svizzera italiana - SUPSI',
#  'Forschungsanstalten Agroscope - AGS',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Forschungsanstalten Agroscope - AGS',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Forschungsanstalten Agroscope - AGS',
#  'SUP della Svizzera italiana - SUPSI',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Forschungsanstalten Agroscope - AGS',
#  'Allergie- und Asthmaforschung - SIAF',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Allergie- und Asthmaforschung - SIAF',
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  "Centre de rech. sur l'environnement alpin - CREALP",
#  'Université de Neuchâtel - NE',
#  'Inst. universit. romand de Santé au Travail - IST',
#  'Université de Neuchâtel - NE',
#  'SUP della Svizzera italiana - SUPSI',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Friedrich Miescher Institute - FMI',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Université de Neuchâtel - NE',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Inst. universit. romand de Santé au Travail - IST',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Université de Neuchâtel - NE',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Université de Neuchâtel - NE',
#  'Friedrich Miescher Institute - FMI',
#  'Université de Neuchâtel - NE',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Université de Neuchâtel - NE',
#  'SUP della Svizzera italiana - SUPSI',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Université de Neuchâtel - NE',
#  'Allergie- und Asthmaforschung - SIAF',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  "Centre de rech. sur l'environnement alpin - CREALP",
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Université de Neuchâtel - NE',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Université de Neuchâtel - NE',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'SUP della Svizzera italiana - SUPSI',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Allergie- und Asthmaforschung - SIAF',
#  'Université de Neuchâtel - NE',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Forschungsanstalten Agroscope - AGS',
#  'Forschungsanstalten Agroscope - AGS',
#  'Université de Neuchâtel - NE',
#  'Swiss Center for Electronics and Microtech. - CSEM',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Swiss Center for Electronics and Microtech. - CSEM',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Inst. universit. romand de Santé au Travail - IST',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Ente Ospedaliero Cantonale - EOC',
#  'Allergie- und Asthmaforschung - SIAF',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Inst. universit. romand de Santé au Travail - IST',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Friedrich Miescher Institute - FMI',
#  'Université de Neuchâtel - NE',
#  'HES de Suisse occidentale - HES-SO',
#  'Swiss Center for Electronics and Microtech. - CSEM',
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Forschungsanstalten Agroscope - AGS',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'AO Research Institute - AORI',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  "Centre de rech. sur l'environnement alpin - CREALP",
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'SUP della Svizzera italiana - SUPSI',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Idiap Research Institute - IDIAP',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Université de Neuchâtel - NE',
#  'Forschungsanstalten Agroscope - AGS',
#  'SUP della Svizzera italiana - SUPSI',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Université de Neuchâtel - NE',
#  'SUP della Svizzera italiana - SUPSI',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Université de Neuchâtel - NE',
#  'Forschungsanstalten Agroscope - AGS',
#  'Université de Neuchâtel - NE',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'HES de Suisse occidentale - HES-SO',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Forschungsanstalten Agroscope - AGS',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Université de Neuchâtel - NE',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Berner Fachhochschule - BFH',
#  'Université de Neuchâtel - NE',
#  'Forschungsanstalten Agroscope - AGS',
#  'Forschungsanstalten Agroscope - AGS',
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Forschungsanstalten Agroscope - AGS',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Forschungsanstalten Agroscope - AGS',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Forschungsanstalten Agroscope - AGS',
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Forschungsanstalten Agroscope - AGS',
#  'Université de Neuchâtel - NE',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'SUP della Svizzera italiana - SUPSI',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'SUP della Svizzera italiana - SUPSI',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Idiap Research Institute - IDIAP',
#  'Inst. universit. romand de Santé au Travail - IST',
#  'SUP della Svizzera italiana - SUPSI',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Idiap Research Institute - IDIAP',
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Inst. universit. romand de Santé au Travail - IST',
#  'Université de Neuchâtel - NE',
#  'Swiss Center for Electronics and Microtech. - CSEM',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Zürcher Fachhochschule (ohne PH) - ZFH',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Université de Neuchâtel - NE',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  "Centre de rech. sur l'environnement alpin - CREALP",
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Forschungsanstalten Agroscope - AGS',
#  'Forschungsanstalten Agroscope - AGS',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Allergie- und Asthmaforschung - SIAF',
#  'Idiap Research Institute - IDIAP',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Université de Neuchâtel - NE',
#  'Allergie- und Asthmaforschung - SIAF',
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  "Centre de rech. sur l'environnement alpin - CREALP",
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Allergie- und Asthmaforschung - SIAF',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Université de Neuchâtel - NE',
#  'Forschungsinstitut für biologischen Landbau - FIBL',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Idiap Research Institute - IDIAP',
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Forschungsanstalten Agroscope - AGS',
#  'Université de Neuchâtel - NE',
#  'Ente Ospedaliero Cantonale - EOC',
#  'Université de Neuchâtel - NE',
#  'Ente Ospedaliero Cantonale - EOC',
#  'Friedrich Miescher Institute - FMI',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'SUP della Svizzera italiana - SUPSI',
#  'Université de Neuchâtel - NE',
#  'Zürcher Fachhochschule (ohne PH) - ZFH',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Forschungsanstalten Agroscope - AGS',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Université de Neuchâtel - NE',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'HES de Suisse occidentale - HES-SO',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Université de Neuchâtel - NE',
#  'Schweizer Paraplegiker Forschung - SPF',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Université de Neuchâtel - NE',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Université de Neuchâtel - NE',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Friedrich Miescher Institute - FMI',
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Université de Neuchâtel - NE',
#  'Friedrich Miescher Institute - FMI',
#  'Université de Neuchâtel - NE',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Université de Neuchâtel - NE',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Inst. universit. romand de Santé au Travail - IST',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Forschungsanstalten Agroscope - AGS',
#  'Forschungsanstalten Agroscope - AGS',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'HES de Suisse occidentale - HES-SO',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Forschungsinstitut für Opthalmologie - IRO',
#  'Université de Neuchâtel - NE',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Idiap Research Institute - IDIAP',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'SUP della Svizzera italiana - SUPSI',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Idiap Research Institute - IDIAP',
#  'Swiss Center for Electronics and Microtech. - CSEM',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#  'Université de Neuchâtel - NE',
#  'Université de Neuchâtel - NE',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  ...]

# %% [markdown]
# We see that some unmapped universities include the canton name, hence we can improve this. We also added a special case to map 'Inst. de Hautes Etudes Internat. et du Dév - IHEID'. Same for the Tessin (Ticino) because we later saw on the map that the Tessin is not really represented.
#
# There, we see another issue: The use of abbreviations prevents the Google API from finding the university. (Still, this is a bit strange, we thought Google Search would be good enough to recognize abbreviations.) Another problem is 'Eidg. Anstalt für Wasserversorgung - EAWAG', where 'Eidg.' stands for 'Eidgenössische'. A search on Wikipedia reveals that this name refers to three places in Switzerland, what we expect because this institution concern water supply.

# %%
cantonNames = ['ZH', 'BE', 'LU', 'UR', 'SZ', 'OW', 'NW', 'GL', 'ZG', 'FR', 'SO', 'BS', 'BL', 'SH', 'AR', 'AI', 'SG', 'GR', 'AG', 'TG', 'TI', 'VD', 'VS', 'NE', 'GE', 'JU']
cantonNamesDict = {'Zürcher': 'ZH', 'Berner': 'BE'}

# search for a canton abbreviation in the university name
# also treat two universities specially
def findCanton(univName):
    if univName == 'Inst. de Hautes Etudes Internat. et du Dév - IHEID':
        return 'GE'
    if univName == 'SUP della Svizzera italiana - SUPSI':
        return 'TI'
    for canton in cantonNames:
        cantonStr = " " + canton
        if cantonStr in univName:
            return canton
        
    for alternativeCantonName in cantonNamesDict:
        if alternativeCantonName in univName:
            return cantonNamesDict[alternativeCantonName]
    
    return None


universityNameToCantonImproved = {}
for univName in universityNameToCanton:
    canton = universityNameToCanton[univName]
    if canton is None:
        canton = findCanton(univName)
    universityNameToCantonImproved[univName] = canton

    
nonMappedUniversityNamesImproved = list(filter(lambda key: universityNameToCantonImproved[key] is None, df.University))
nonMappedUniversityNamesImproved
# Out:
# ['Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Schweiz. Institut für Kunstwissenschaft - SIK-ISEA',
#  'HES de Suisse occidentale - HES-SO',
#  'Schweiz. Institut für Kunstwissenschaft - SIK-ISEA',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Schweiz. Institut für Kunstwissenschaft - SIK-ISEA',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Schweiz. Institut für Kunstwissenschaft - SIK-ISEA',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Swiss Center for Electronics and Microtech. - CSEM',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Swiss Center for Electronics and Microtech. - CSEM',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Swiss Center for Electronics and Microtech. - CSEM',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Swiss Center for Electronics and Microtech. - CSEM',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'AO Research Institute - AORI',
#  'Allergie- und Asthmaforschung - SIAF',
#  'AO Research Institute - AORI',
#  'Forschungsinstitut für biologischen Landbau - FIBL',
#  'AO Research Institute - AORI',
#  'Friedrich Miescher Institute - FMI',
#  'Friedrich Miescher Institute - FMI',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Allergie- und Asthmaforschung - SIAF',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'AO Research Institute - AORI',
#  'AO Research Institute - AORI',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Friedrich Miescher Institute - FMI',
#  'Allergie- und Asthmaforschung - SIAF',
#  'Forschungsinstitut für biologischen Landbau - FIBL',
#  'Ente Ospedaliero Cantonale - EOC',
#  'Allergie- und Asthmaforschung - SIAF',
#  'Inst. universit. romand de Santé au Travail - IST',
#  'Inst. universit. romand de Santé au Travail - IST',
#  'Friedrich Miescher Institute - FMI',
#  'Allergie- und Asthmaforschung - SIAF',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Forschungsinstitut für biologischen Landbau - FIBL',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Friedrich Miescher Institute - FMI',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Allergie- und Asthmaforschung - SIAF',
#  'Ente Ospedaliero Cantonale - EOC',
#  'Inst. universit. romand de Santé au Travail - IST',
#  'Allergie- und Asthmaforschung - SIAF',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'AO Research Institute - AORI',
#  'Inst. universit. romand de Santé au Travail - IST',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Inst. universit. romand de Santé au Travail - IST',
#  'Ente Ospedaliero Cantonale - EOC',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Friedrich Miescher Institute - FMI',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Allergie- und Asthmaforschung - SIAF',
#  'Ente Ospedaliero Cantonale - EOC',
#  'AO Research Institute - AORI',
#  'Friedrich Miescher Institute - FMI',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Inst. universit. romand de Santé au Travail - IST',
#  'Ente Ospedaliero Cantonale - EOC',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Inst. universit. romand de Santé au Travail - IST',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Swiss Center for Electronics and Microtech. - CSEM',
#  'Eidg. Hochschulinstitut für Berufsbildung - EHB',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Hochschulinstitut für Berufsbildung - EHB',
#  'Swiss Center for Electronics and Microtech. - CSEM',
#  'Swiss Center for Electronics and Microtech. - CSEM',
#  'Swiss Center for Electronics and Microtech. - CSEM',
#  'Swiss Center for Electronics and Microtech. - CSEM',
#  'Swiss Center for Electronics and Microtech. - CSEM',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Hochschulinstitut für Berufsbildung - EHB',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Schweiz. Institut für Kunstwissenschaft - SIK-ISEA',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Schweiz. Institut für Kunstwissenschaft - SIK-ISEA',
#  'Eidg. Hochschulinstitut für Berufsbildung - EHB',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Swiss Center for Electronics and Microtech. - CSEM',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Allergie- und Asthmaforschung - SIAF',
#  'Allergie- und Asthmaforschung - SIAF',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  "Centre de rech. sur l'environnement alpin - CREALP",
#  'Inst. universit. romand de Santé au Travail - IST',
#  'Friedrich Miescher Institute - FMI',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Inst. universit. romand de Santé au Travail - IST',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Friedrich Miescher Institute - FMI',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Allergie- und Asthmaforschung - SIAF',
#  "Centre de rech. sur l'environnement alpin - CREALP",
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Allergie- und Asthmaforschung - SIAF',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Swiss Center for Electronics and Microtech. - CSEM',
#  'Swiss Center for Electronics and Microtech. - CSEM',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Inst. universit. romand de Santé au Travail - IST',
#  'Ente Ospedaliero Cantonale - EOC',
#  'Allergie- und Asthmaforschung - SIAF',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Inst. universit. romand de Santé au Travail - IST',
#  'Friedrich Miescher Institute - FMI',
#  'HES de Suisse occidentale - HES-SO',
#  'Swiss Center for Electronics and Microtech. - CSEM',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'AO Research Institute - AORI',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  "Centre de rech. sur l'environnement alpin - CREALP",
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Idiap Research Institute - IDIAP',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'HES de Suisse occidentale - HES-SO',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Idiap Research Institute - IDIAP',
#  'Inst. universit. romand de Santé au Travail - IST',
#  'Idiap Research Institute - IDIAP',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Inst. universit. romand de Santé au Travail - IST',
#  'Swiss Center for Electronics and Microtech. - CSEM',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  "Centre de rech. sur l'environnement alpin - CREALP",
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Allergie- und Asthmaforschung - SIAF',
#  'Idiap Research Institute - IDIAP',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Allergie- und Asthmaforschung - SIAF',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  "Centre de rech. sur l'environnement alpin - CREALP",
#  'Allergie- und Asthmaforschung - SIAF',
#  'Forschungsinstitut für biologischen Landbau - FIBL',
#  'Idiap Research Institute - IDIAP',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Ente Ospedaliero Cantonale - EOC',
#  'Ente Ospedaliero Cantonale - EOC',
#  'Friedrich Miescher Institute - FMI',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'HES de Suisse occidentale - HES-SO',
#  'Schweizer Paraplegiker Forschung - SPF',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Friedrich Miescher Institute - FMI',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Friedrich Miescher Institute - FMI',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Inst. universit. romand de Santé au Travail - IST',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'HES de Suisse occidentale - HES-SO',
#  'Forschungsinstitut für Opthalmologie - IRO',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Idiap Research Institute - IDIAP',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Idiap Research Institute - IDIAP',
#  'Swiss Center for Electronics and Microtech. - CSEM',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Swiss Center for Electronics and Microtech. - CSEM',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Forschungsinstitut für biologischen Landbau - FIBL',
#  'Friedrich Miescher Institute - FMI',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'Swiss Center for Electronics and Microtech. - CSEM',
#  'Friedrich Miescher Institute - FMI',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'HES de Suisse occidentale - HES-SO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Idiap Research Institute - IDIAP',
#  'Idiap Research Institute - IDIAP',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Ente Ospedaliero Cantonale - EOC',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Idiap Research Institute - IDIAP',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  "Centre de rech. sur l'environnement alpin - CREALP",
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Hochschulinstitut für Berufsbildung - EHB',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Allergie- und Asthmaforschung - SIAF',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'AO Research Institute - AORI',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Schweiz. Institut für Kunstwissenschaft - SIK-ISEA',
#  'Idiap Research Institute - IDIAP',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Allergie- und Asthmaforschung - SIAF',
#  'Allergie- und Asthmaforschung - SIAF',
#  'Idiap Research Institute - IDIAP',
#  'Idiap Research Institute - IDIAP',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  "Centre de rech. sur l'environnement alpin - CREALP",
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'HES de Suisse occidentale - HES-SO',
#  'Inst. universit. romand de Santé au Travail - IST',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Friedrich Miescher Institute - FMI',
#  'Idiap Research Institute - IDIAP',
#  'Eidg. Hochschulinstitut für Berufsbildung - EHB',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Forschungsinstitut für biologischen Landbau - FIBL',
#  'Inst. universit. romand de Santé au Travail - IST',
#  'Forschungsinstitut für Opthalmologie - IRO',
#  'Allergie- und Asthmaforschung - SIAF',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Idiap Research Institute - IDIAP',
#  'Forschungsinstitut für Opthalmologie - IRO',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Idiap Research Institute - IDIAP',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Idiap Research Institute - IDIAP',
#  'Idiap Research Institute - IDIAP',
#  'Idiap Research Institute - IDIAP',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Idiap Research Institute - IDIAP',
#  'Ente Ospedaliero Cantonale - EOC',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Idiap Research Institute - IDIAP',
#  'Idiap Research Institute - IDIAP',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Inst. universit. romand de Santé au Travail - IST',
#  'Forschungsinstitut für Opthalmologie - IRO',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'HES de Suisse occidentale - HES-SO',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Idiap Research Institute - IDIAP',
#  'Idiap Research Institute - IDIAP',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Swiss Center for Electronics and Microtech. - CSEM',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Friedrich Miescher Institute - FMI',
#  'Inst. universit. romand de Santé au Travail - IST',
#  'Idiap Research Institute - IDIAP',
#  'Forschungsinstitut für Opthalmologie - IRO',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Fachhochschule Ostschweiz - FHO',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Idiap Research Institute - IDIAP',
#  'Idiap Research Institute - IDIAP',
#  'Idiap Research Institute - IDIAP',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Idiap Research Institute - IDIAP',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'HES de Suisse occidentale - HES-SO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Friedrich Miescher Institute - FMI',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Allergie- und Asthmaforschung - SIAF',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Idiap Research Institute - IDIAP',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Forschungsinstitut für Opthalmologie - IRO',
#  'Inst. Suisse de Spéléologie et Karstologie - ISSKA',
#  'Swiss Institute of Bioinformatics - SIB',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Idiap Research Institute - IDIAP',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Fachhochschule Ostschweiz - FHO',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'HES de Suisse occidentale - HES-SO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Idiap Research Institute - IDIAP',
#  'Idiap Research Institute - IDIAP',
#  'Idiap Research Institute - IDIAP',
#  'Forschungsinstitut für Opthalmologie - IRO',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Allergie- und Asthmaforschung - SIAF',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'Allergie- und Asthmaforschung - SIAF',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Friedrich Miescher Institute - FMI',
#  'HES de Suisse occidentale - HES-SO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Forschungsinstitut für Opthalmologie - IRO',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Idiap Research Institute - IDIAP',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Friedrich Miescher Institute - FMI',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Idiap Research Institute - IDIAP',
#  'HES de Suisse occidentale - HES-SO',
#  'Idiap Research Institute - IDIAP',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'HES de Suisse occidentale - HES-SO',
#  'Inst. universit. romand de Santé au Travail - IST',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Idiap Research Institute - IDIAP',
#  'Friedrich Miescher Institute - FMI',
#  'Friedrich Miescher Institute - FMI',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'HES de Suisse occidentale - HES-SO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'HES de Suisse occidentale - HES-SO',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Allergie- und Asthmaforschung - SIAF',
#  "Centre de rech. sur l'environnement alpin - CREALP",
#  'Idiap Research Institute - IDIAP',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Allergie- und Asthmaforschung - SIAF',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Inst. universit. romand de Santé au Travail - IST',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'Fachhochschule Ostschweiz - FHO',
#  'Forschungskommission SAGW',
#  'HES de Suisse occidentale - HES-SO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'HES de Suisse occidentale - HES-SO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'HES de Suisse occidentale - HES-SO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'HES de Suisse occidentale - HES-SO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'HES de Suisse occidentale - HES-SO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Istituto Svizzero di Roma - ISR',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Swiss Institute of Bioinformatics - SIB',
#  'Swiss Institute of Bioinformatics - SIB',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'HES de Suisse occidentale - HES-SO',
#  'Inst. Suisse de Spéléologie et Karstologie - ISSKA',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Ente Ospedaliero Cantonale - EOC',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Swiss Institute of Bioinformatics - SIB',
#  'Schweiz. Institut für Kunstwissenschaft - SIK-ISEA',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Inst. universit. romand de Santé au Travail - IST',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Fachhochschule Ostschweiz - FHO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Inst. universit. romand de Santé au Travail - IST',
#  'Inst. universit. romand de Santé au Travail - IST',
#  'Pädag. Hochschule Tessin (Teilschule SUPSI) - ASP',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Idiap Research Institute - IDIAP',
#  'HES de Suisse occidentale - HES-SO',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'HES de Suisse occidentale - HES-SO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Allergie- und Asthmaforschung - SIAF',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'HES de Suisse occidentale - HES-SO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Idiap Research Institute - IDIAP',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'HES de Suisse occidentale - HES-SO',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Haute école pédagogique fribourgeoise - HEPFR',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'HES de Suisse occidentale - HES-SO',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'HES de Suisse occidentale - HES-SO',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'HES de Suisse occidentale - HES-SO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Inst. universit. romand de Santé au Travail - IST',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'HES de Suisse occidentale - HES-SO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'HES de Suisse occidentale - HES-SO',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Fachhochschule Ostschweiz - FHO',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'AO Research Institute - AORI',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'HES de Suisse occidentale - HES-SO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Friedrich Miescher Institute - FMI',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Inst. universit. romand de Santé au Travail - IST',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'HES de Suisse occidentale - HES-SO',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Fachhochschule Ostschweiz - FHO',
#  'Idiap Research Institute - IDIAP',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'HES de Suisse occidentale - HES-SO',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'HES de Suisse occidentale - HES-SO',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Allergie- und Asthmaforschung - SIAF',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Allergie- und Asthmaforschung - SIAF',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'HES de Suisse occidentale - HES-SO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'HES de Suisse occidentale - HES-SO',
#  'Inst. universit. romand de Santé au Travail - IST',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'HES de Suisse occidentale - HES-SO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'HES de Suisse occidentale - HES-SO',
#  'Friedrich Miescher Institute - FMI',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Allergie- und Asthmaforschung - SIAF',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Swiss Institute of Bioinformatics - SIB',
#  'HES de Suisse occidentale - HES-SO',
#  'Idiap Research Institute - IDIAP',
#  'Idiap Research Institute - IDIAP',
#  'HES de Suisse occidentale - HES-SO',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Swiss Institute of Bioinformatics - SIB',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'HES de Suisse occidentale - HES-SO',
#  'Haute école pédagogique fribourgeoise - HEPFR',
#  'Idiap Research Institute - IDIAP',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'HES de Suisse occidentale - HES-SO',
#  'Haute école pédagogique fribourgeoise - HEPFR',
#  'Haute école pédagogique fribourgeoise - HEPFR',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Allergie- und Asthmaforschung - SIAF',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'HES de Suisse occidentale - HES-SO',
#  'Forschungsinstitut für biologischen Landbau - FIBL',
#  'Forschungsinstitut für biologischen Landbau - FIBL',
#  'Fachhochschule Ostschweiz - FHO',
#  'HES de Suisse occidentale - HES-SO',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'HES de Suisse occidentale - HES-SO',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Fachhochschule Ostschweiz - FHO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Fachhochschule Ostschweiz - FHO',
#  'Fachhochschule Ostschweiz - FHO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'HES de Suisse occidentale - HES-SO',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'HES de Suisse occidentale - HES-SO',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Idiap Research Institute - IDIAP',
#  'HES de Suisse occidentale - HES-SO',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'AO Research Institute - AORI',
#  'AO Research Institute - AORI',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Swiss Institute of Bioinformatics - SIB',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Istituto Svizzero di Roma - ISR',
#  'Friedrich Miescher Institute - FMI',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Friedrich Miescher Institute - FMI',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Swiss Center for Electronics and Microtech. - CSEM',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'HES de Suisse occidentale - HES-SO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'Allergie- und Asthmaforschung - SIAF',
#  'Fachhochschule Kalaidos - FHKD',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Forschungsinstitut für Opthalmologie - IRO',
#  'Istituto Svizzero di Roma - ISR',
#  'Friedrich Miescher Institute - FMI',
#  'HES de Suisse occidentale - HES-SO',
#  'Schweizer Kompetenzzentrum Sozialwissensch. - FORS',
#  'Schweizer Kompetenzzentrum Sozialwissensch. - FORS',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Idiap Research Institute - IDIAP',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'HES de Suisse occidentale - HES-SO',
#  'Schweiz. Institut für Kunstwissenschaft - SIK-ISEA',
#  'Friedrich Miescher Institute - FMI',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'Friedrich Miescher Institute - FMI',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Pädag. Hochschule Tessin (Teilschule SUPSI) - ASP',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Schweizer Kompetenzzentrum Sozialwissensch. - FORS',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'HES de Suisse occidentale - HES-SO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Istituto Svizzero di Roma - ISR',
#  'Istituto Svizzero di Roma - ISR',
#  'HES de Suisse occidentale - HES-SO',
#  'Schweizer Kompetenzzentrum Sozialwissensch. - FORS',
#  'HES de Suisse occidentale - HES-SO',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Swiss Institute of Bioinformatics - SIB',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Friedrich Miescher Institute - FMI',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'HES de Suisse occidentale - HES-SO',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Idiap Research Institute - IDIAP',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Forschungsinstitut für Opthalmologie - IRO',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'HES de Suisse occidentale - HES-SO',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Friedrich Miescher Institute - FMI',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'HES de Suisse occidentale - HES-SO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Istituto Svizzero di Roma - ISR',
#  'Friedrich Miescher Institute - FMI',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'HES de Suisse occidentale - HES-SO',
#  'Friedrich Miescher Institute - FMI',
#  'HES de Suisse occidentale - HES-SO',
#  'HES de Suisse occidentale - HES-SO',
#  'Fachhochschule Ostschweiz - FHO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'HES de Suisse occidentale - HES-SO',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Fachhochschule Ostschweiz - FHO',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'HES de Suisse occidentale - HES-SO',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'HES de Suisse occidentale - HES-SO',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'HES de Suisse occidentale - HES-SO',
#  'Idiap Research Institute - IDIAP',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#  'Inst. universit. romand de Santé au Travail - IST',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Idiap Research Institute - IDIAP',
#  'Forschungsinstitut für Opthalmologie - IRO',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Swiss Institute of Bioinformatics - SIB',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Allergie- und Asthmaforschung - SIAF',
#  'HES de Suisse occidentale - HES-SO',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Friedrich Miescher Institute - FMI',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'HES de Suisse occidentale - HES-SO',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Schweizer Kompetenzzentrum Sozialwissensch. - FORS',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'HES de Suisse occidentale - HES-SO',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Inst. Suisse de Spéléologie et Karstologie - ISSKA',
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Material und Prüfungsanstalt - EMPA',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG',
#  ...]

# %%
nbGrantsMapped = findNumberUnmappedUniversities(universityNameToCantonImproved)

print("Percentage of grants mapped: {}".format(nbGrantsMapped/totalNbGrants))
# Out:
# Percentage of grants mapped: University    0.959615
# dtype: float64

# %% [markdown]
# We reached the required percentage of 95%.

# %% [markdown]
# # Putting the Results on a Map

# %% [markdown]
# We add a new column to the dataframe that specifies the canton to which the grant was awarded.

# %%
df['canton'] = df['University'].apply(lambda univName: universityNameToCantonImproved[univName])
df.head(2)
# Out:
#    ﻿"Project Number"                                      Project Title  \
# 1                  4  Batterie de tests à l'usage des enseignants po...
# 3                  6  Katalog der datierten Handschriften in der Sch...
#
#   Project Title English Responsible Applicant            Funding Instrument  \
# 1                   NaN    Massarenti Léonard  Project funding (Div. I-III)
# 3                   NaN        Burckhardt Max  Project funding (Div. I-III)
#
#   Funding Instrument Hierarchy  \
# 1              Project funding
# 3              Project funding
#
#                                          Institution  \
# 1  Faculté de Psychologie et des Sciences de l'Ed...
# 3  Abt. Handschriften und Alte Drucke Bibliothek ...
#
#                   University  Discipline Number  \
# 1  Université de Genève - GE              10104
# 3     Universität Basel - BS              10302
#
#                     Discipline Name  \
# 1  Educational science and Pedagogy
# 3                     Swiss history
#
#                            Discipline Name Hierarchy  Start Date    End Date  \
# 1  Human and Social Sciences;Psychology, educatio...  01.10.1975  30.09.1976
# 3  Human and Social Sciences;Theology & religious...  01.10.1975  30.09.1976
#
#   Approved Amount Keywords canton
# 1        41022.00      NaN     GE
# 3        52627.00      NaN     BS

# %% [markdown]
# We create the dataframe for the map and aggregate the total amount of money received per canton.

# %%
df_per_canton = df[['canton', 'Approved Amount']]

# remove data with no money indicated
df_per_canton = df_per_canton[df_per_canton['Approved Amount'] != 'data not included in P3']

# convert string to int and convert to MCHF, group by canton
df_per_canton['Approved Amount'] = df_per_canton['Approved Amount'].apply(lambda x: round(float(x)/1e6, 1)) # convert to million
df_per_canton = df_per_canton.groupby('canton').sum()

# we need the dataframe to have all cantons, even if the money they receive is 0 CHF
df_per_canton_H = pd.DataFrame({'canton': cantonNames, 'Approved Amount': 0})
df_per_canton_H = df_per_canton_H.set_index(['canton'])
df_per_canton_H.update(df_per_canton)
df_per_canton = df_per_canton_H

df_per_canton = df_per_canton.reset_index()
#df_per_canton['canton']
df_per_canton.head(2)
# Out:
#   canton  Approved Amount
# 0     ZH           3509.1
# 1     BE           1544.9

# %% [markdown]
# We finally plot the results on a map.

# %%
state_geo = r'ch-cantons.topojson.json'

geoMap = folium.Map(location=[46.8, 8.3], zoom_start=8)
geoMap.choropleth(geo_path=state_geo, data=df_per_canton,
             columns=['canton', 'Approved Amount'],
             key_on='feature.id', topojson='objects.cantons',
             fill_color='BuPu', fill_opacity=0.7, line_opacity=0.2,
             legend_name='Unemployment Rate (%)')
geoMap.save('swiss_funds.html')
geoMap
# Out:
# /home/maximilian/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:9: FutureWarning: 'threshold_scale' default behavior has changed. Now you get a linear scale between the 'min' and the 'max' of your data. To get former behavior, use folium.utilities.split_six.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %% [markdown]
# The map above corresponds to our expectation that Zurich and Lausanne receive much more money than the rest. We may investigate more into why the Tessin area does not have any money, it happens because we didn't parse it correctly.

# %% [markdown]
# # Code Stubs

# %%
#dir(location[0])

badGeolocator = Nominatim()

latitude = location[0].latitude
longitude = location[0].longitude
badLocation = badGeolocator.geocode(query={'lat':latitude, 'lon': longitude, 'country': 'CH'}, exactly_one=False, addressdetails=True)
badLocation

# %%
badGeolocator = Nominatim()
badLocation = badGeolocator.geocode(query={'city': 'Dübendorf', 'country': 'CH'}, exactly_one=False, addressdetails=True)
badLocation[0]
